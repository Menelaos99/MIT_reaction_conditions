# %%
import glob
import json
import numpy as np

# Find all JSON files in the directory
json_files = glob.glob('*.json')

# Load each JSON file
data = []
for file in json_files:
    with open(file, 'r') as f:
        json_data = json.load(f)
        data.append(json_data)

# Print the loaded data
print(data)
# Out:
# [[{'params': {'featurisation': 'composition', 'model_type': 'NN', 'task': 'sint', 'use_only_target': False, 'concat': False}, 'train_maes': [0.5473208427429199, 0.10880847567649082, 0.32751113176345825, 0.3097604987926261, 0.11172799427400935, 0.18892347991857514, 0.31695055464903515, 0.23081059710451188, 0.21337819627897683, 0.16553567835064822], 'test_maes': [170.9062957763672, 106.48534393310547, 119.09357452392578, 121.0313491821289, 105.73383331298828, 115.35198211669922, 123.24876403808594, 105.70211791992188, 114.39136505126953, 103.64432525634766], 'val_maes': [153.42063903808594, 160.51971435546875, 160.4394989013672, 163.7823486328125, 162.015869140625, 154.47280883789062, 145.1959991455078, 150.78089904785156, 165.07337951660156, 164.50479125976562]}, {'params': {'featurisation': 'composition', 'model_type': 'NN', 'task': 'sint', 'use_only_target': False, 'concat': False}, 'train_maes': [0.5473208427429199, 0.10880847567649082, 0.32751113176345825, 0.3097604987926261, 0.11
# ...

# %%
json_files
# Out:
# ['results_2024-09-02 07:30:31.744590.json',
#  'results_2024-08-30 18:30:55.424603.json',
#  'results_2024-08-29 16:57:02.470342.json',
#  'results_2024-08-31 15:40:06.525042.json',
#  'results_2024-08-24 10:48:23.119510.json',
#  'results_2024-08-31 09:39:11.775702.json',
#  'results_2024-08-30 07:10:25.343526.json',
#  'results_2024-08-29 16:59:27.265492.json',
#  'results_2024-08-29 08:17:03.578280.json',
#  'results_2024-08-23 23:14:04.511759.json',
#  'results_2024-08-24 11:10:09.809704.json',
#  'results_2024-08-29 07:41:27.079822.json',
#  'results_2024-08-24 11:01:06.744054.json',
#  'results_2024-08-29 19:54:34.908055.json']

# %%
import json

file_path = '/home/students/code/MLP/Menelaos/reaction_conditions/MLP/results/results_2024-09-04 18:39:48.610182.json'
file_path = '/home/students/code/MLP/Menelaos/reaction_conditions/MLP/results/results_2024-09-04 19:18:56.264181.json'
file_path = '/home/students/code/MLP/Menelaos/reaction_conditions/MLP/results/results_2024-09-04 19:10:59.251851.json'
file_path = '/home/students/code/MLP/Menelaos/reaction_conditions/MLP/results/results_2024-09-05 19:04:36.830694.json'
#file_path = '/home/students/code/MLP/Menelaos/reaction_conditions/MLP/results/results_2024-09-04 20:00:03.594580.json'
with open(file_path, 'r') as f:
    json_data = json.load(f)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

item = json_data

# Prepare lists to store each column's data
model_types = []
featurisations = []
concats = []
use_only_targets = []
train_maes = []
test_maes = []
all_test_maes = []

# Iterate over the results and populate the lists
for run in item:
    model_types.append(run['params']['model_type'])
    featurisations.append(run['params']['featurisation'])
    try: 
        concats.append(run['params']['concat'])
    except:   
        concats.append('None')
    use_only_targets.append(run['params']['use_only_target'])
    train_maes.append(np.mean(run["train_maes"]))
    test_maes.append(np.mean(run["test_maes"]))
    all_test_maes.append(run["test_maes"])

df = pd.DataFrame({
    'Model Type': model_types,
    'Featurisation': featurisations,
    'Concat': concats,
    'Use Only Target': use_only_targets,
    'Train MAE': train_maes,
    'Test MAE': test_maes,
    'Test std': [np.std(x) for x in all_test_maes],
    'All Test MAEs': all_test_maes
})

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target  Train MAE    Test MAE  \
# 0        GNN  mtencoder_512   None            False   0.215804  100.014221
# 1        GNN  mtencoder_256   None            False   0.207871  100.676967
# 2        GNN    composition   None            False   0.245094  106.314236
# 3        GNN     matscibert   None            False   0.274186  138.079887
# 4        GNN       matminer   None            False   0.381621  124.213193
#
#     Test std                                      All Test MAEs
# 0   3.509239  [106.85814535010675, 97.9052237374442, 99.4050...
# 1   5.382839  [110.40964514690897, 93.91619020071089, 99.850...
# 2   5.785576  [105.14557244910957, 100.46426732791878, 114.6...
# 3  25.706602  [121.27049617411927, 125.40911289001843, 134.3...
# 4   2.575358  [124.17079103837102, 127.17690979383006, 123.7...

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target   Train MAE    Test MAE  \
# 0        GNN  mtencoder_512   None            False    0.219695   99.798904
# 1         NN  mtencoder_512  False            False    0.260731  109.319006
# 2        XGB  mtencoder_512  False            False  159.022837  153.477507
# 3        GNN  mtencoder_256   None            False    0.207037   99.679593
# 4         NN  mtencoder_256  False            False    0.262931  112.015611
# 5        XGB  mtencoder_256  False            False  160.253686  152.325858
#
#     Test std                                      All Test MAEs
# 0   3.670071  [101.68218126000825, 97.5566349764048, 102.929...
# 1   4.259638  [115.82857513427734, 110.09002685546875, 102.5...
# 2  10.094178  [161.91876351619112, 157.08827681452593, 155.0...
# 3   4.858978  [100.29141440065752, 95.35921422354183, 105.90...
# 4   5.202183  [120.8281478881836, 108.74786376953125, 114.94...
# ...

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target  Train MAE    Test MAE  \
# 0        GNN  mtencoder_512   None            False   0.206103  109.115552
# 1        GNN  mtencoder_256   None            False   0.250496  108.785088
# 2        GNN    composition   None            False   0.209613  102.164278
# 3        GNN     matscibert   None            False   0.241077  145.803755
# 4        GNN       matminer   None            False   0.389780  134.606292
#
#    Test std         All Test MAEs
# 0       0.0  [109.11555247810317]
# 1       0.0  [108.78508835312742]
# 2       0.0  [102.16427835973893]
# 3       0.0  [145.80375479941043]
# 4       0.0  [134.60629226968896]

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target  Train MAE    Test MAE  \
# 0        GNN  mtencoder_512   None            False   0.206103  109.115552
# 1        GNN  mtencoder_256   None            False   0.250496  108.785088
#
#    Test std         All Test MAEs
# 0       0.0  [109.11555247810317]
# 1       0.0  [108.78508835312742]

# %%
df
# Out:
#   Model Type  Featurisation  Concat  Use Only Target   Train MAE    Test MAE  \
# 0        XGB  mtencoder_512   False            False  159.657521  159.266641
# 1        XGB  mtencoder_256   False            False  165.234435  161.389487
# 2        XGB    composition   False            False  177.697133  171.439191
# 3        XGB     matscibert   False            False  187.685249  184.699707
# 4        XGB       matminer   False            False  186.388396  172.302910
#
#    Test std         All Test MAEs
# 0       0.0  [159.26664074378476]
# 1       0.0   [161.3894868725131]
# 2       0.0   [171.4391906940468]
# 3       0.0  [184.69970689982853]
# 4       0.0   [172.3029101082306]

# %%
df
# Out:
#   Model Type       Featurisation  Concat  Use Only Target  Train MAE  \
# 0         NN  mtencoder_pretrain   False            False   0.191247
# 1         NN       mtencoder_256   False            False   0.272657
# 2         NN         composition   False            False   0.318623
# 3         NN          matscibert   False            False   0.563909
# 4         NN            matminer   False            False   0.353655
#
#      Test MAE  Test std         All Test MAEs
# 0  102.612160       0.0   [102.6121597290039]
# 1  119.100067       0.0  [119.10006713867188]
# 2  117.290672       0.0   [117.2906723022461]
# 3  164.488800       0.0  [164.48880004882812]
# 4  129.484482       0.0  [129.48448181152344]

# %%
df
# Out:
#   Model Type       Featurisation  Concat  Use Only Target  Train MAE  \
# 0         NN  mtencoder_pretrain   False            False   0.398073
# 1         NN       mtencoder_256   False            False   0.460995
# 2         NN         composition   False            False   0.376989
# 3         NN          matscibert   False            False   0.567591
# 4         NN            matminer   False            False   0.484356
#
#      Test MAE  Test std         All Test MAEs
# 0  138.072189       0.0   [138.0721893310547]
# 1  150.956604       0.0  [150.95660400390625]
# 2  132.159363       0.0  [132.15936279296875]
# 3  177.821732       0.0   [177.8217315673828]
# 4  162.655655       0.0  [162.65565490722656]

# %%
df
# Out:
#   Model Type       Featurisation Concat  Use Only Target  Train MAE  \
# 0        GNN  mtencoder_pretrain   None            False   0.375006
# 1        GNN       mtencoder_256   None            False   0.356643
# 2        GNN         composition   None            False   0.425009
# 3        GNN          matscibert   None            False   0.439094
# 4        GNN            matminer   None            False   0.424699
#
#      Test MAE  Test std         All Test MAEs
# 0  133.969137       0.0  [133.96913732682697]
# 1  132.566225       0.0   [132.5662246988427]
# 2  141.895750       0.0   [141.8957496785229]
# 3  155.462695       0.0   [155.4626950850398]
# 4  146.905145       0.0  [146.90514460024627]

# %%
df
# Out:
#   Model Type       Featurisation Concat  Use Only Target  Train MAE  \
# 0        GNN  mtencoder_pretrain   None            False   0.387673
# 1         NN  mtencoder_pretrain  False            False   0.381591
# 2        GNN         composition   None            False   0.325088
# 3         NN         composition  False            False   0.289397
# 4        GNN          matscibert   None            False   0.398636
# 5         NN          matscibert  False            False   0.516905
# 6        GNN            matminer   None            False   0.392092
# 7         NN            matminer  False            False   0.480488
#
#      Test MAE  Test std         All Test MAEs
# 0  134.614904       0.0  [134.61490379949535]
# 1  134.874771       0.0  [134.87477111816406]
# 2  126.191672       0.0  [126.19167226471517]
# 3  123.269508       0.0   [123.2695083618164]
# 4  142.120078       0.0  [142.12007814016403]
# 5  177.489075       0.0  [177.48907470703125]
# ...

# %%
df
# Out:
#   Model Type       Featurisation Concat  Use Only Target  Train MAE  \
# 0        GNN  mtencoder_pretrain   None            False    0.35832
# 1         NN  mtencoder_pretrain  False            False    0.37125
#
#      Test MAE  Test std         All Test MAEs
# 0  127.157708       0.0  [127.15770775457347]
# 1  132.315399       0.0  [132.31539916992188]

# %%
df
# Out:
#   Model Type       Featurisation Concat  Use Only Target  Train MAE  \
# 0        GNN  mtencoder_pretrain   None            False    0.35832
#
#      Test MAE  Test std         All Test MAEs
# 0  127.157708       0.0  [127.15770775457347]

# %%
df
# Out:
#   Model Type  Featurisation  Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN  mtencoder_256   False            False   0.405455  132.079272
#
#    Test std                                      All Test MAEs
# 0  6.175647  [140.3904571533203, 133.72958374023438, 121.50...

# %%
df
# Out:
#   Model Type Featurisation  Concat  Use Only Target  Train MAE   Test MAE  \
# 0         NN   composition   False            False   0.339913  122.18396
#
#    Test std                                      All Test MAEs
# 0  7.402378  [123.054931640625, 128.822509765625, 120.24348...

# %%
df
# Out:
#   Model Type Featurisation  Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN   composition    True            False   0.143719  107.087936
#
#    Test std                                      All Test MAEs
# 0  6.828118  [113.15593719482422, 110.36536407470703, 97.37...

# %%
df
# Out:
#   Model Type Featurisation  Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN   composition    True            False   0.125113  107.044203
#
#    Test std                                      All Test MAEs
# 0  3.249966  [111.85790252685547, 108.52125549316406, 102.5...

# %%
df
# Out:
#   Model Type  Featurisation  Concat  Use Only Target   Train MAE    Test MAE  \
# 0        XGB    composition    True            False  174.717396  159.111145
# 1        XGB     matscibert    True            False  156.577759  137.169376
# 2        XGB  mtencoder_768    True            False  155.994075  144.590383
# 3        XGB  mtencoder_512    True            False  159.444707  144.310166
# 4        XGB       matminer    True            False  170.864760  155.040323
#
#     Test std                                      All Test MAEs
# 0   5.501615  [165.15997988240812, 156.61443700872206, 152.5...
# 1   4.336002  [143.22000730147272, 140.05708877396492, 132.8...
# 2   5.147899  [142.94571000188034, 146.93172646776102, 143.9...
# 3   8.138158  [150.86918689040664, 140.95995179035015, 134.7...
# 4  20.707808  [180.84034055089853, 179.86367128288137, 137.0...

# %%
df
# Out:
#   Model Type Featurisation  Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN   composition    True            False   0.183963  109.293164
#
#    Test std                                      All Test MAEs
# 0   5.93159  [114.58177185058594, 105.70258331298828, 99.27...

# %%
df
# Out:
#   Model Type  Featurisation  Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN    composition    True            False   0.252599  122.675331
# 1         NN     matscibert    True            False   0.499652  160.166132
# 2         NN  mtencoder_768    True            False   0.375626  133.607913
# 3         NN  mtencoder_512    True            False   0.339255  125.767413
# 4         NN       matminer    True            False   0.282166  125.379207
#
#     Test std                                      All Test MAEs
# 0  27.673849  [175.95663452148438, 106.49703216552734, 101.8...
# 1  23.878019  [154.53662109375, 156.07211303710938, 206.3821...
# 2  16.847863  [122.58511352539062, 166.88070678710938, 126.4...
# 3   4.805537  [128.8934326171875, 118.31482696533203, 126.10...
# 4  17.961791  [160.99420166015625, 117.33757781982422, 113.1...

# %%
df
# Out:
#   Model Type Featurisation  Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN   composition   False            False   0.252073  118.558895
# 1         NN   composition   False            False   0.252073  118.558895
#
#     Test std                                      All Test MAEs
# 0  18.693022  [170.9062957763672, 106.48534393310547, 119.09...
# 1  18.693022  [170.9062957763672, 106.48534393310547, 119.09...

# %%
np.mean(df['All Test MAEs'].loc[0][1:])
# Out:
# np.float64(125.66168403625488)

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target  Train MAE    Test MAE  \
# 0        GNN  mtencoder_512   None            False   0.345167  122.017701
# 1        GNN  mtencoder_256   None            False   0.419772  133.165951
# 2        GNN       matminer   None            False   0.384747  132.761631
# 3        GNN    composition   None            False   0.368730  126.577566
# 4        GNN     matscibert   None            False   0.405402  141.003370
#
#                                        All Test MAEs
# 0  [124.42767066718629, 124.75470190581328, 116.8...
# 1  [142.01870412885773, 133.31450244595544, 126.1...
# 2  [139.79864331357967, 141.45996575207442, 123.8...
# 3  [132.71605417950553, 135.36610679863404, 119.2...
# 4  [169.09261895410762, 128.7593681761937, 137.33...

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN  mtencoder_512  False            False   0.360928  126.022700
# 1         NN  mtencoder_512  False            False   0.360928  126.022700
# 2        GNN  mtencoder_512   None            False   0.384204  126.132393
# 3         NN  mtencoder_256  False            False   0.388802  131.277856
# 4         NN  mtencoder_256  False            False   0.388802  131.277856
# 5        GNN  mtencoder_256   None            False   0.391627  128.143441
# 6         NN       matminer  False            False   0.372418  135.936008
# 7         NN       matminer  False            False   0.372418  135.936008
#
#                                        All Test MAEs
# 0  [133.41429138183594, 133.10150146484375, 127.3...
# 1  [133.41429138183594, 133.10150146484375, 127.3...
# 2  [137.57484672972873, 129.8903735806483, 114.41...
# 3  [139.11705017089844, 147.8783721923828, 120.04...
# ...

# %%
df
# Out:
#   Model Type  Featurisation  Concat  Use Only Target  Train MAE  Test MAE  \
# 0         NN  mtencoder_512   False            False   0.360928  126.0227
# 1         NN  mtencoder_512   False            False   0.360928  126.0227
#
#                                        All Test MAEs
# 0  [133.41429138183594, 133.10150146484375, 127.3...
# 1  [133.41429138183594, 133.10150146484375, 127.3...

# %%
df
# Out:
#   Model Type  Featurisation Concat  Use Only Target  Train MAE    Test MAE  \
# 0         NN  mtencoder_512  False            False   0.346525  124.472646
# 1         NN  mtencoder_512  False            False   0.346525  124.472646
# 2        GNN  mtencoder_512   None            False   0.356948  121.126715
# 3         NN  mtencoder_256   True            False   0.363482  128.886894
#
#                                        All Test MAEs
# 0  [127.04651641845703, 130.227783203125, 117.936...
# 1  [127.04651641845703, 130.227783203125, 117.936...
# 2  [130.36432578519265, 132.80881961798815, 111.4...
# 3  [130.0135040283203, 132.39578247070312, 127.92...

# %%
df
# Out:
#   Model Type  Featurisation  Use Only Target  Train MAE    Test MAE  \
# 0        GNN  mtencoder_256            False   0.388336  126.590759
# 1         NN  mtencoder_256            False   0.400505  130.347371
#
#                                        All Test MAEs
# 0  [136.29237117411927, 131.2185694345036, 116.01...
# 1  [133.46499633789062, 133.7028350830078, 125.17...

# %%
df
# Out:
#   Model Type  Featurisation  Use Only Target  Train MAE    Test MAE  \
# 0         NN  mtencoder_256            False   0.343903  128.221103
#
#                                        All Test MAEs
# 0  [129.16456604003906, 132.5605010986328, 127.10...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'data[-1]' is your input list of dictionaries
item = data[3]

# Prepare lists to store each column's data
model_types = []
featurisations = []
concats = []
use_only_targets = []
train_maes = []
test_maes = []
all_test_maes = []

# Iterate over the results and populate the lists
for run in item:
    model_types.append(run['params']['model_type'])
    featurisations.append(run['params']['featurisation'])
    concats.append(run['params']['concat'])
    use_only_targets.append(run['params']['use_only_target'])
    train_maes.append(np.mean(run["train_maes"]))
    test_maes.append(np.mean(run["test_maes"]))
    all_test_maes.append(run["test_maes"])

# Create a DataFrame
df = pd.DataFrame({
    'Model Type': model_types,
    'Featurisation': featurisations,
    'Concat': concats,
    'Use Only Target': use_only_targets,
    'Train MAE': train_maes,
    'Test MAE': test_maes,
    'All Test MAEs': all_test_maes
})



df
# Out:
# /home/students/.conda/envs/synthesis/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/students/.conda/envs/synthesis/lib/python3.9/site-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   Model Type Featurisation  Concat  Use Only Target  Train MAE  Test MAE  \
# 0        XGB     mtencoder    True            False        NaN       NaN
# 1        XGB      matminer    True            False        NaN       NaN
# 2        XGB   composition    True            False        NaN       NaN
#
#   All Test MAEs
# 0            []
# 1            []
# 2            []

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv, GATConv, GINConv, Sequential

class GNN(torch.nn.Module):
    def __init__(self, in_channels=None, hidden_channels=None, nn_layers=None, nn_units=None, conv_type='GCN'):
        super(GNN, self).__init__()
        self.conv_type = conv_type
        self.gcn = GCNConv(in_channels, hidden_channels)
        self.gat = GATConv(in_channels, hidden_channels)
        # i think we will mostly use the GAT and GCN
        self.gin = GINConv(
            Sequential('x, edge_index', [
                (torch.nn.Linear(in_channels, hidden_channels), 'x -> x'),
                torch.nn.ReLU(),
                (torch.nn.Linear(hidden_channels, hidden_channels), 'x -> x')
            ])
        )
        # self.lin = torch.nn.Linear(hidden_channels, 1)
        self.lin = NN(hidden_channels, n_layers=nn_layers, n_units=nn_units)

    def forward(self, x, edge_index, batch):
        if self.conv_type == 'GCN':
            x = self.gcn(x, edge_index) 
        elif self.conv_type == 'GAT':
            x = self.gat(x, edge_index)
        elif self.conv_type == 'GIN':
            x = self.gin(x, edge_index)
        
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x
    
class NN(nn.Module):
    def __init__(self, input_dim, n_layers, n_units):
        super(NN, self).__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        
        layers = []
        in_features = input_dim
        for i in range(self.n_layers):
            layers.append(nn.Linear(in_features, n_units[i]))
            layers.append(nn.ReLU())
            in_features = n_units[i]
        layers.append(nn.Linear(in_features, 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %%
network = GNN(in_channels=512, hidden_channels=2, nn_units=[10, 10], nn_layers=2, conv_type='GAT')

# %%
network
# Out:
# GNN(
#   (gcn): GCNConv(512, 2)
#   (gat): GATConv(512, 2, heads=1)
#   (gin): GINConv(nn=Sequential(
#     (0): Linear(in_features=512, out_features=2, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=2, out_features=2, bias=True)
#   ))
#   (lin): NN(
#     (model): Sequential(
#       (0): Linear(in_features=2, out_features=10, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=10, out_features=10, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=10, out_features=1, bias=True)
#     )
#   )
# )

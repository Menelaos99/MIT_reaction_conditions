# %%
import pandas as pd
import numpy as np
import json
from util.classes import *

filename = r'solid-state_dataset_20200713.json'
filedata = open(filename, mode='r').read()
jsonParse = json.loads(filedata)

import glob
# Define the path to the folder containing the CSV files
folder_path = 'sinter_dataset/*.csv'

# Use glob to match all csv file paths in the folder
csv_files = glob.glob(folder_path)

# Initialize an empty list to store dataframes
dfs = []

# Loop through the list of csv file paths
for file in csv_files:
    # Read the current csv file into a dataframe
    df = pd.read_csv(file)
    # Append the dataframe to the list of dataframes
    dfs.append(df)

# Concatenate all dataframes in the list into a single dataframe
merged_df = pd.concat(dfs, ignore_index=True)
merged_df = merged_df.groupby('formula').agg(lambda x: list(set(x))).reset_index().drop(columns=['Unnamed: 0']).set_index('formula')

# Display the merged dataframe
print(merged_df)

# %%
# Use from_dict to parse the nested dictionaries
reactions = [from_dict(reaction, ReactionEntry) for reaction in jsonParse['reactions']]

# %%
reactions[0].precursors
# Out:
# [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#  Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)]

# %%
# Filter the DataFrame to find rows where the 'target' list length is greater than 1
filtered_df = merged_df[merged_df['target'].apply(lambda x: len(x) > 1)]

# Display the filtered DataFrame
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [target]
# Index: []

# %%
reactions[5].operations
# Out:
# [Operation(type='StartingSynthesis', token='synthesized', conditions=OperationConditions(heating_temperature=None, heating_time=None, heating_atmosphere=None, mixing_device=None, mixing_media=None)),
#  Operation(type='HeatingOperation', token='calcined', conditions=OperationConditions(heating_temperature=[OperationValue(min_value=800.0, max_value=800.0, values=[800.0], units='°C')], heating_time=[OperationValue(min_value=24.0, max_value=24.0, values=[24.0], units='h')], heating_atmosphere=['air'], mixing_device=None, mixing_media=None)),
#  Operation(type='MixingOperation', token='mixed', conditions=OperationConditions(heating_temperature=None, heating_time=None, heating_atmosphere=None, mixing_device=None, mixing_media=None)),
#  Operation(type='MixingOperation', token='stirred', conditions=OperationConditions(heating_temperature=None, heating_time=None, heating_atmosphere=None, mixing_device=None, mixing_media='water')),
#  Operation(type='MixingOperation', token='added', conditions=OperationConditions(heating_temperature=None, heating_time=None, heating_atmosphere=None, mixing_device='LiAlO2', mixing_media=None)),
#  Operation(type='MixingOperation', token='added', conditions=OperationConditions(heating_temperature=None, heating_time=None, heating_atmosphere=None, mixing_device=None, mixing_media=None)),
#  Operation(type='MixingOperation', token='stirred', conditions=OperationConditions(heating_temperature=[OperationValue(min_value=70.0, max_value=80.0, values=[], units='°C')], heating_time=[OperationValue(min_value=1.0, max_value=2.0, values=[], units='h')], heating_atmosphere=None, mixing_device=None, mixing_media=None)),
#  Operation(type='DryingOperation', token='dried', conditions=OperationConditions(heating_temperature=[OperationValue(min_value=120.0, max_value=120.0, values=[120.0], units='°C')], heating_time=None, heating_atmosphere=['air'], mixing_device=None, mixing_media=None)),
#  Operation(type='HeatingOperation', token='calcined', conditions=OperationConditions(heating_temperature=[OperationValue(min_value=600.0, max_value=600.0, values=[600.0], units='°C')], heating_time=[OperationValue(min_value=5.0, max_value=5.0, values=[5.0], units='h')], heating_atmosphere=['air'], mixing_device=None, mixing_media=None))]

# %%
len(reactions)
# Out:
# 31782

# %%
[x.precursors for x in reactions if "titanate" in x.target.material_string]
# Out:
# [[Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='potassium carbonate', material_formula='K2CO3', material_name='potassium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titania', material_formula='TiO2', material_name='titania', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='potassium carbonate', material_formula='K2CO3', material_name='potassium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titania', material_formula='TiO2', material_name='titania', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='barium carbonate: BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titanium dioxide: TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='strontium carbonate: SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Barium Carbonate', material_formula='BaCO3', material_name='Barium Carbonate', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Nb2O5', material_formula='Nb2O5', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Nb2O5', amount='1', elements={'Nb': '2', 'O': '5'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Nb2O5', material_formula='Nb2O5', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Nb2O5', amount='1', elements={'Nb': '2', 'O': '5'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Na2CO3', material_formula='Na2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Na2CO3', amount='1', elements={'Na': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Na2CO3', material_formula='Na2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Na2CO3', amount='1', elements={'Na': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Alumina', material_formula='Al2O3', material_name='alumina', phase=None, is_acronym=False, composition=[Composition(formula='Al2O3', amount='1', elements={'Al': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titania', material_formula='TiO2', material_name='titania', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='rutile TiO2', material_formula='TiO2', material_name='rutile', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='corundum Al2O3', material_formula='Al2O3', material_name='corundum', phase=None, is_acronym=False, composition=[Composition(formula='Al2O3', amount='1', elements={'Al': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='rutile TiO2', material_formula='TiO2', material_name='rutile', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='corundum Al2O3', material_formula='Al2O3', material_name='corundum', phase=None, is_acronym=False, composition=[Composition(formula='Al2O3', amount='1', elements={'Al': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Barium Carbonate', material_formula='BaCO3', material_name='Barium Carbonate', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Na2CO3', material_formula='Na2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Na2CO3', amount='1', elements={'Na': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='ZnO', material_formula='ZnO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZnO', amount='1', elements={'Zn': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Cs2CO3', material_formula='Cs2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Cs2CO3', amount='1', elements={'Cs': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='La2O3,(', material_formula='La2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='La2O3', amount='1', elements={'La': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='LiOH·H2O', material_formula='LiOH·H2O', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='LiOH', amount='1', elements={'Li': '1', 'O': '1', 'H': '1'}), Composition(formula='H2O', amount='1', elements={'H': '2', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='H2TiO3', material_formula='H2TiO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='H2TiO3', amount='1', elements={'H': '2', 'Ti': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Na2CO3', material_formula='Na2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Na2CO3', amount='1', elements={'Na': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='titanium dioxide', material_formula='TiO2', material_name='titanium dioxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='CoO', material_formula='CoO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='CoO', amount='1', elements={'Co': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Ho2O3', material_formula='Ho2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Ho2O3', amount='1', elements={'Ho': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='La2O3', material_formula='La2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='La2O3', amount='1', elements={'La': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Er2O3', material_formula='Er2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Er2O3', amount='1', elements={'Er': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Y2O3', material_formula='Y2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Y2O3', amount='1', elements={'Y': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiNb2O7', material_formula='TiNb2O7', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiNb2O7', amount='1', elements={'Ti': '1', 'Nb': '2', 'O': '7'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Ti2Nb10O29', material_formula='Ti2Nb10O29', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Ti2Nb10O29', amount='1', elements={'Ti': '2', 'Nb': '10', 'O': '29'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Barium hydroxide', material_formula='Ba(OH)2', material_name='Barium hydroxide', phase=None, is_acronym=False, composition=[Composition(formula='Ba(OH)2', amount='1', elements={'O': '2', 'H': '2', 'Ba': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titania', material_formula='TiO2', material_name='titania', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Bi4Ti3O12', material_formula='Bi4Ti3O12', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi4Ti3O12', amount='1', elements={'Bi': '4', 'Ti': '3', 'O': '12'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bismuth (III) nitrate pentahydrate', material_formula='Bi(NO3)3·5H2O', material_name='Bismuth (III) nitrate pentahydrate', phase=None, is_acronym=False, composition=[Composition(formula='Bi(NO3)3', amount='1', elements={'N': '3', 'O': '9', 'Bi': '1'}), Composition(formula='H2O', amount='5', elements={'H': '2', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Iron oxide Fe2O3', material_formula='Fe2O3', material_name='Iron oxide', phase=None, is_acronym=False, composition=[Composition(formula='Fe2O3', amount='1', elements={'Fe': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titanium dioxide', material_formula='TiO2', material_name='titanium dioxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='barium acetate', material_formula='Ba(CH3COO)2', material_name='barium acetate', phase=None, is_acronym=False, composition=[Composition(formula='Ba(CH3COO)2', amount='1', elements={'C': '4', 'H': '6', 'O': '4', 'Ba': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titanium iso-propoxide', material_formula='Ti(OCH(CH3)2)4', material_name='titanium isopropoxide', phase=None, is_acronym=False, composition=[Composition(formula='Ti(OCH(CH3)2)4', amount='1', elements={'C': '12', 'H': '28', 'O': '4', 'Ti': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='anatase TiO2', material_formula='TiO2', material_name='anatase', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='CaO', material_formula='CaO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='CaO', amount='1', elements={'Ca': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='excess-TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='excess-TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='LiOH·H2O', material_formula='LiOH·H2O', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='LiOH', amount='1', elements={'Li': '1', 'O': '1', 'H': '1'}), Composition(formula='H2O', amount='1', elements={'H': '2', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='LiOH·H2O', material_formula='LiOH·H2O', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='LiOH', amount='1', elements={'Li': '1', 'O': '1', 'H': '1'}), Composition(formula='H2O', amount='1', elements={'H': '2', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Potassium carbonate', material_formula='K2CO3', material_name='Potassium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='NiO', material_formula='NiO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='NiO', amount='1', elements={'Ni': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Cs2CO3', material_formula='Cs2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Cs2CO3', amount='1', elements={'Cs': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='barium carbonate', material_formula='BaCO3', material_name='barium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titanium dioxide', material_formula='TiO2', material_name='titanium dioxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='titania', material_formula='TiO2', material_name='titania', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaO', material_formula='BaO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaO', amount='1', elements={'Ba': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Potassium carbonate', material_formula='K2CO3', material_name='Potassium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='lithium carbonate', material_formula='Li2CO3', material_name='lithium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titanium dioxide', material_formula='TiO2', material_name='titanium dioxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='La2O3', material_formula='La2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='La2O3', amount='1', elements={'La': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Titanium IV Oxide', material_formula='TiO2', material_name='Titanium IV Oxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Barium Carbonate', material_formula='BaCO3', material_name='Barium Carbonate', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='MgO', material_formula='MgO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='MgO', amount='1', elements={'Mg': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Cs2CO3', material_formula='Cs2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Cs2CO3', amount='1', elements={'Cs': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='CaO', material_formula='CaO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='CaO', amount='1', elements={'Ca': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2 anatase', material_formula='TiO2', material_name='anatase', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Fe2O3', material_formula='Fe2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Fe2O3', amount='1', elements={'Fe': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='rutile TiO2', material_formula='TiO2', material_name='rutile', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Al2O3', material_formula='Al2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Al2O3', amount='1', elements={'Al': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='barium oxide', material_formula='BaO', material_name='barium oxide', phase=None, is_acronym=False, composition=[Composition(formula='BaO', amount='1', elements={'Ba': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Barium carbonate BaCO3', material_formula='BaCO3', material_name='Barium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='titanium dioxide TiO2', material_formula='TiO2', material_name='titanium dioxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='K2CO3', material_formula='K2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='K2CO3', amount='1', elements={'K': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='CaO', material_formula='CaO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='CaO', amount='1', elements={'Ca': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='CuO', material_formula='CuO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='CuO', amount='1', elements={'Cu': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='MgO', material_formula='MgO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='MgO', amount='1', elements={'Mg': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
# ...
#   Material(material_string='titanium oxide', material_formula='TiO2', material_name='titanium oxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Barium carbonate BaCO3', material_formula='BaCO3', material_name='Barium carbonate', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Titanium oxide TiO2(99', material_formula='TiO2', material_name='Titanium oxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Sm2O3(99.9', material_formula='Sm2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Sm2O3', amount='1', elements={'Sm': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Dy2O3', material_formula='Dy2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Dy2O3', amount='1', elements={'Dy': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Pb3O4', material_formula='Pb3O4', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Pb3O4', amount='1', elements={'Pb': '3', 'O': '4'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Bi2O3', material_formula='Bi2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Bi2O3', amount='1', elements={'Bi': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='Pb3O4', material_formula='Pb3O4', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Pb3O4', amount='1', elements={'Pb': '3', 'O': '4'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='ZrO2', material_formula='ZrO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Li2CO3', material_formula='Li2CO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Li2CO3', amount='1', elements={'Li': '2', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='La2O3', material_formula='La2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='La2O3', amount='1', elements={'La': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='BaCO3', material_formula='BaCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='BaCO3', amount='1', elements={'Ba': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='PbO', material_formula='PbO', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='PbO', amount='1', elements={'Pb': '1', 'O': '1'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Gd2O3', material_formula='Gd2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Gd2O3', amount='1', elements={'Gd': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='titanium oxide', material_formula='TiO2', material_name='titanium oxide', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='zirconium oxide', material_formula='ZrO2', material_name='zirconium oxide', phase=None, is_acronym=False, composition=[Composition(formula='ZrO2', amount='1', elements={'Zr': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='lead oxide', material_formula='PbO2', material_name='lead oxide', phase=None, is_acronym=False, composition=[Composition(formula='PbO2', amount='1', elements={'Pb': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Gd2O3', material_formula='Gd2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Gd2O3', amount='1', elements={'Gd': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)],
#  [Material(material_string='SrCO3', material_formula='SrCO3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='SrCO3', amount='1', elements={'Sr': '1', 'C': '1', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='TiO2', material_formula='TiO2', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='TiO2', amount='1', elements={'Ti': '1', 'O': '2'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None),
#   Material(material_string='Gd2O3', material_formula='Gd2O3', material_name='', phase=None, is_acronym=False, composition=[Composition(formula='Gd2O3', amount='1', elements={'Gd': '2', 'O': '3'})], amount_vars={}, element_vars={}, additives=[], oxygen_deficiency=None)]]

# %%
def PreprocessElementCombinationData(data: List[FormulaPart]):
    return sorted(data, key= lambda item: item.material)


def GetElementInfoForIndex(data: List[FormulaPart], index: int, property : str = "Element"):
    if(index >= len(data)): return None
    print(len(data), index)
    if(property.lower()[0]=='e'):
        return data[index].material
    else:
        return data[index].amount

def flatten(data: ReactionEntry):

    # Pre-processing
    rxn_lhs = PreprocessElementCombinationData(data.reaction.left_side)
    rxn_rhs = PreprocessElementCombinationData(data.reaction.right_side)

    payload = {}
    payload['DOI']                                   = data.doi
    payload['Paragraph String']                      = data.paragraph_string
    payload['Synthesis Type']                        = data.synthesis_type
    payload['Rxn String']                            = data.reaction_string
    payload['Rxn Element Substitution']              = data.reaction.element_substitution
    payload['Rxn LHS 1 Material']                    = GetElementInfoForIndex(rxn_lhs, 0, "Element")
    payload['Rxn LHS 2 Material']                    = GetElementInfoForIndex(rxn_lhs, 1, "Element")
    payload['Rxn LHS 3 Material']                    = GetElementInfoForIndex(rxn_lhs, 2, "Element")
    payload['Rxn LHS 4 Material']                    = GetElementInfoForIndex(rxn_lhs, 3, "Element")
    payload['Rxn LHS 5 Material']                    = GetElementInfoForIndex(rxn_lhs, 4, "Element")
    payload['Rxn LHS 6 Material']                    = GetElementInfoForIndex(rxn_lhs, 5, "Element")
    payload['Rxn LHS 7 Material']                    = GetElementInfoForIndex(rxn_lhs, 6, "Element")
    payload['Rxn LHS 8 Material']                    = GetElementInfoForIndex(rxn_lhs, 7, "Element")
    payload['Rxn LHS 9 Material']                    = GetElementInfoForIndex(rxn_lhs, 8, "Element")
    payload['Rxn LHS 10 Material']                   = GetElementInfoForIndex(rxn_lhs, 9, "Element")
    payload['Rxn LHS 1 Amount']                      = GetElementInfoForIndex(rxn_lhs, 0, "Amount")
    payload['Rxn LHS 2 Amount']                      = GetElementInfoForIndex(rxn_lhs, 1, "Amount")
    payload['Rxn LHS 3 Amount']                      = GetElementInfoForIndex(rxn_lhs, 2, "Amount")
    payload['Rxn LHS 4 Amount']                      = GetElementInfoForIndex(rxn_lhs, 3, "Amount")
    payload['Rxn LHS 5 Amount']                      = GetElementInfoForIndex(rxn_lhs, 4, "Amount")
    payload['Rxn LHS 6 Amount']                      = GetElementInfoForIndex(rxn_lhs, 5, "Amount")
    payload['Rxn LHS 7 Amount']                      = GetElementInfoForIndex(rxn_lhs, 6, "Amount")
    payload['Rxn LHS 8 Amount']                      = GetElementInfoForIndex(rxn_lhs, 7, "Amount")
    payload['Rxn LHS 9 Amount']                      = GetElementInfoForIndex(rxn_lhs, 8, "Amount")
    payload['Rxn LHS 10 Amount']                     = GetElementInfoForIndex(rxn_lhs, 9, "Amount")
    payload['Rxn RHS 1 Material']                    = GetElementInfoForIndex(rxn_rhs, 0, "Element")
    payload['Rxn RHS 2 Material']                    = GetElementInfoForIndex(rxn_rhs, 1, "Element")
    payload['Rxn RHS 3 Material']                    = GetElementInfoForIndex(rxn_rhs, 2, "Element")
    payload['Rxn RHS 4 Material']                    = GetElementInfoForIndex(rxn_rhs, 3, "Element")
    payload['Rxn RHS 5 Material']                    = GetElementInfoForIndex(rxn_rhs, 4, "Element")  
    payload['Rxn RHS 1 Amount']                      = GetElementInfoForIndex(rxn_rhs, 0, "Amount")
    payload['Rxn RHS 2 Amount']                      = GetElementInfoForIndex(rxn_rhs, 1, "Amount")
    payload['Rxn RHS 3 Amount']                      = GetElementInfoForIndex(rxn_rhs, 2, "Amount")
    payload['Rxn RHS 4 Amount']                      = GetElementInfoForIndex(rxn_rhs, 3, "Amount")
    payload['Rxn RHS 5 Amount']                      = GetElementInfoForIndex(rxn_rhs, 4, "Amount")
    return payload
